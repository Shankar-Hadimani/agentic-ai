# %%
from langgraph.graph import Graph
from langchain_groq import ChatGroq
from dotenv import load_dotenv, find_dotenv
from getpass import getpass
import os

# %%
# Load environment variables
dotenv_path = find_dotenv()
if dotenv_path:
    print(f"Loading .env file from: {dotenv_path}")
    load_dotenv(dotenv_path)
else:
    print("No .env file found.")

# Set GROQ_API_KEY API key
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["HUGGINGFACE_API_KEY"]=os.getenv("HUGGINGFACE_API_KEY")
# Out:
# Loading .env file from: /home/azureuser/agentic-ai-1/.env

# %%
llm=ChatGroq(model="llama3-70b-8192")

# %%
llm.invoke("Hello how are you?").content
# Out:
# "I'm just a language model, I don't have emotions, but I'm functioning properly and ready to help you with any questions or tasks you may have! How can I assist you today?"

# %%
from typing import List, Annotated, Sequence, Tuple, Union, TypedDict, Dict, Any
from langchain import hub
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field, validator
from langgraph.graph.message import add_messages
from langgraph.prebuilt import tools_condition, ToolNode
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.tools.retriever import create_retriever_tool
from langgraph .graph import END, START, StateGraph
from sentence_transformers import SentenceTransformer

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
from langchain_groq import ChatGroq

llm=ChatGroq(model="Gemma2-9b-It")

llm.invoke("Hello how are you?").content
# Out:
# "As an AI, I don't have feelings, but I'm here and ready to help! How can I assist you today?\n"

# %%
embeddings=HuggingFaceEmbeddings(model="all-MiniLM-L6-v2", api_key=os.getenv("HUGGINGFACE_API_KEY"))
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 embeddings=HuggingFaceEmbeddings(model="all-MiniLM-L6-v2", api_key=os.getenv("HUGGINGFACE_API_KEY"))
#
# File ~/agentic-ai/agai_venv/lib/python3.12/site-packages/langchain_huggingface/embeddings/huggingface.py:50, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      48 def __init__(self, **kwargs: Any):
#      49     """Initialize the sentence_transformer."""
# ---> 50     super().__init__(**kwargs)
#      51     try:
#      52         import sentence_transformers  # type: ignore[import]
#
# File ~/agentic-ai/agai_venv/lib/python3.12/site-packages/pydantic/main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# ...
